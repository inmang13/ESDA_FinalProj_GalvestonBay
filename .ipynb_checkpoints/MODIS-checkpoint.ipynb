# %%
import glob
import os
import requests
import json
import time
from pathlib import Path
import xarray as xr
from datetime import datetime
import pandas as pd
import rasterio
import matplotlib.pyplot as plt
import numpy as np
import netCDF4 as nc


#set current working directory
os.chdir('/home/jovyan')

#list files in shared folder
files = glob.glob("/shared_space/Galveston_Bay/*")
files
# Out:
# ['/shared_space/Galveston_Bay/water_temp',
#  '/shared_space/Galveston_Bay/all_basin_data_subset.csv',
#  '/shared_space/Galveston_Bay/MODIS_test',
#  '/shared_space/Galveston_Bay/RMD_Combined_Field.csv',
#  '/shared_space/Galveston_Bay/MODIS_250',
#  '/shared_space/Galveston_Bay/TST_Monitoring_Data_May2025_for_HGAC_Website.xlsx',
#  '/shared_space/Galveston_Bay/MODIS_files',
#  '/shared_space/Galveston_Bay/SWQM_Stations.csv',
#  '/shared_space/Galveston_Bay/resultphyschem.csv']

# %% [markdown]
# ### log into earthdata

# %%
#directory we are working in  
destDir = os.getcwd()

#location for new files
dest_fp = "/shared_space/Galveston_Bay/MODIS_250"

if not os.path.exists(dest_fp):
    os.makedirs(dest_fp)

print("Exists?", os.path.exists(dest_fp))
print("Is directory?", os.path.isdir(dest_fp))
# Out:
# Exists? True
# Is directory? True

# %%
#api link
API = "https://appeears.earthdatacloud.nasa.gov/api/"

#Earthdata Login credentials
username = 'mrfalk'
password = 'dataPlease12471!'

#token that is needed to get data
login_response = requests.post(
    f"{API}login",
    auth=(username, password)
)

if login_response.status_code != 200:
    raise Exception(f"Login failed: {login_response.text}")

token = login_response.json()['token']
headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {token}"
}

# %% [markdown]
# ### explore available data

# %%
#this explores products available 
# request all products in the product service
product_response = requests.get('{}product'.format(API)).json()

# Create a dictionary indexed by product name & version           
products = {p['ProductAndVersion']: p for p in product_response}

#I think this is the product we will use for temperature 
product_name = 'MYD09GQ.061' #MYD09A1.061  #MYD11A1.061 #MYD09GQ
products[product_name]  #this has measurements everyday, there is also a version with measurement ecery 8 days
# Out:
# {'Product': 'MYD09GQ',
#  'Platform': 'Aqua MODIS',
#  'Description': 'Surface Reflectance Bands 1-2',
#  'RasterType': 'Tile',
#  'Resolution': '250m',
#  'TemporalGranularity': 'Daily',
#  'Version': '061',
#  'Available': True,
#  'DocLink': 'https://doi.org/10.5067/MODIS/MYD09GQ.061',
#  'Source': 'LP DAAC',
#  'TemporalExtentStart': '2002-07-04',
#  'TemporalExtentEnd': 'Present',
#  'Deleted': False,
#  'DOI': '10.5067/MODIS/MYD09GQ.061',
#  'Info': {'provider_id': 'lp_prod'},
#  'ProductAndVersion': 'MYD09GQ.061'}

# %%
# Request layers for the 2nd product (index 1) in the list: MOD11A1.061
lst_response = requests.get('{}product/{}'.format(API,product_name)).json()
#shows available bands 
list(lst_response.keys())
# Out:
# ['QC_250m_1',
#  'granule_pnt_1',
#  'iobs_res_1',
#  'num_observations',
#  'obscov_1',
#  'orbit_pnt_1',
#  'sur_refl_b01_1',
#  'sur_refl_b02_1']

# %% [markdown]
# ### set up task

# %%
#Define bounding box as GeoJSON FeatureCollection
#chose bounding box based a frame that only required one block of earthdata
#this bounding box may not be the entire region that we want (it doesn't go very far north)
geo = {
    "type": "FeatureCollection",
    "features": [
        {
            "type": "Feature",
            "geometry": {
                "type": "Polygon",
                "coordinates": [[
                    [-96.0, 28.5],
                    [-96.0, 30.0],
                    [-94.0, 30.0],
                    [-94.0, 28.5],
                    [-96.0, 28.5]
                ]]
            },
            "properties": {
                "name": "bbox_area"
            }
        }
    ]
}

# %%
#Define the HLS layer and product you want 
#layer comes from the lst_response

#here chose the emissivity bands for temperature
layers = [
        {'layer': 'sur_refl_b01_1', 'product': product_name},
        {'layer': 'sur_refl_b02_1', 'product': product_name}]
    
#         {'layer': 'sur_refl_b02', 'product': product_name},
#         {'layer': 'sur_refl_b03', 'product': product_name},
#         {'layer': 'sur_refl_b04', 'product': product_name},
#         {'layer': 'sur_refl_b05', 'product': product_name},
#         {'layer': 'sur_refl_b06', 'product': product_name},
#         {'layer': 'sur_refl_b07', 'product': product_name}] 
    #{'layer': 'Emis_32', 'product':product_name}]

# %%
#Create the task the specifics what area to pull
task = {
    "task_type": "area",
    "task_name": "try_for_water2",
    "params": {
        "dates": [
            {
                "startDate": "01-01-2020",
                "endDate": "12-31-2020"
            }
        ],
        "layers": layers,
        "output": {
            "format": {"type": "geotiff"},
            "projection": "geographic"
        },
        "geo": geo
    }
}

#                 "startDate": "05-01-2017",
#                 "endDate": "08-31-2017"

# %% [markdown]
# The below code only needs to be run once- if unsure if the data downloaded, check https://appeears.earthdatacloud.nasa.gov/explore. This is where the requests are stored

# %%
# #Submit the task
# submit_response = requests.post(f"{API}task", headers=headers, json=task)

# if submit_response.status_code != 202:
#     raise Exception(f"Task submission failed: {submit_response.text}")

# task_id = submit_response.json()['task_id']
# print(f"Task submitted. ID: {task_id}")

# # Check task status until it's done
# while True:
#     status_response = requests.get(f"{API}task/{task_id}", headers=headers)
#     status_json = status_response.json()
#     status = status_json['status']
#     print(f"Task status: {status}")
#     if status in ['done', 'failed']:
#         break
#     time.sleep(30)  # Wait 30 seconds between checks

# if status == 'failed':
#     raise Exception("Task failed.")
# Out:
# Task submitted. ID: 714ccd73-e270-47bb-aca1-48d20d9cd49d
# Task status: queued
# Task status: queued
# Task status: queued
# Task status: queued
# Task status: queued
# Task status: queued
# Task status: queued
# Task status: queued
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: processing
# Task status: done

# %% [markdown]
# The below code pulls the above task from the appears website and puts in a bundle (will need task id from the above code or from the website). Once it all runs once and you double check that it in the folder you want, do not run it again for it will duplicate files

# %%
#task_id = '8702722b-f711-49e3-85f8-9ed6bcc85838'

# %%
#task_id
# Out:
# '8702722b-f711-49e3-85f8-9ed6bcc85838'

# %%
# # Call API and return bundle contents for the task_id as json
bundle = requests.get('{}bundle/{}'.format(API,task_id), headers=headers).json()  
#bundle

# %%
# build mapping once (your existing code) 
files = {f['file_id']: f['file_name'] for f in bundle['files']}

# %% [markdown]
# This code just double checks the path you want exists and that the files will actually go there

# %%
dest_fp = "~/shared_space/Galveston_Bay/MODIS_250"
# os.makedirs(dest_fp)
# #
# # Check if the path exists
# print("Exists:", os.path.exists(dest_fp))

# # Check if it's a directory
# print("Is directory:", os.path.isdir(dest_fp))

# # Check if it's writable
# print("Writable:", os.access(dest_fp, os.W_OK))

# Expand ~ to your home directory
dest_fp = os.path.expanduser("~/shared_space/Galveston_Bay/MODIS_250")

# Make sure the directory exists
os.makedirs(dest_fp, exist_ok=True)

print("Saving files to:", dest_fp)
# Out:
# Saving files to: /home/jovyan/shared_space/Galveston_Bay/MODIS_250

# %% [markdown]
# The code below will take the list of files and upload each one to the place you want it. the code chunk below runs for a long time if you have a lot files

# %%
# for file_id, remote_name in files.items():
#     url = f"{API}bundle/{task_id}/{file_id}"
#     resp = requests.get(url, headers=headers, stream=True, allow_redirects=True, timeout=60)
#     try:
#         resp.raise_for_status()
#     except Exception as e:
#         print(f"Download failed for {remote_name}: {e}")
#         continue

#     # choose final filename (adjust logic if your names are nested)
#     if remote_name.endswith('.tif'):
#         filename = os.path.basename(remote_name)  # safer than split('/')[1]
#     else:
#         filename = remote_name

#     filepath = os.path.join(dest_fp, filename)
    
#     # write to disk in chunks
#     with open(filepath, 'wb') as out_fh:
#         for chunk in resp.iter_content(chunk_size=8192):
#             if chunk:
#                 out_fh.write(chunk)

#     print(f"Downloaded: {filepath}")
# Out:
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020001000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020002000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020003000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020004000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020005000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020006000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020007000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020008000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020009000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020010000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020011000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020012000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020013000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020014000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020015000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020016000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020017000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020018000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020019000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020020000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020021000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020022000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020023000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020024000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020025000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020026000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020027000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020028000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020029000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020030000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020031000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020032000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020033000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020034000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020035000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020036000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020037000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020038000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020039000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020040000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020041000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020048000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020049000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020050000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020051000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020052000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020053000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020054000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020055000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020056000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020057000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020058000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020059000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020060000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020061000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020062000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020063000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020064000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020065000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020066000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020067000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020068000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020069000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020070000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020071000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020072000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020073000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020074000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020075000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020076000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020077000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020078000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020079000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020080000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020081000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020082000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020083000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020084000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020085000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020086000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020087000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020088000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020089000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020090000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020091000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020092000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020093000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020094000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020095000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020096000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020097000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020098000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020099000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020100000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020101000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020102000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020103000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020104000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020105000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020106000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020107000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020108000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020109000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020110000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020111000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020112000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020113000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020114000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020115000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020116000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020117000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020118000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020119000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020120000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020121000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020122000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020123000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020124000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020125000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020126000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020127000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020128000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020129000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020130000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020131000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020132000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020133000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020134000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020135000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020136000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020137000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020138000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020139000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020140000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020141000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020142000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020143000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020144000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020145000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020146000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020147000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020148000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020149000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020150000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020151000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020152000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020153000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020154000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020155000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020156000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020157000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020158000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020159000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020160000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020161000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020162000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020163000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020164000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020165000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020166000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020167000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020168000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020169000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020170000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020171000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020172000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020173000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020174000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020175000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020176000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020177000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020178000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020179000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020180000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020181000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020182000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020183000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020184000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020185000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020186000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020187000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020188000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020189000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020190000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020191000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020192000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020193000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020194000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020195000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020196000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020197000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020198000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020199000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020200000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020201000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020202000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020203000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020204000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020205000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020206000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020207000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020208000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020209000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020210000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020211000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020212000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020213000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020214000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020215000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020216000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020217000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020218000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020219000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020220000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020221000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020222000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020223000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020224000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020225000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020226000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020227000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020228000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020229000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020230000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020231000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020232000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020233000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020235000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020236000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020237000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020238000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020239000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020240000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020241000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020242000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020243000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020244000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020245000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020247000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020248000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020249000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020250000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020251000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020252000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020253000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020254000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020255000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020256000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020257000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020258000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020259000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020260000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020261000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020262000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020263000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020264000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020265000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020266000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020267000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020268000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020269000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020270000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020271000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020272000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020273000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020274000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020275000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020276000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020277000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020278000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020279000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020280000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020281000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020282000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020283000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020284000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020285000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020286000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020287000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020288000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020289000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020290000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020291000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020292000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020293000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020294000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020295000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020296000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020297000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020298000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020299000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020300000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020301000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020302000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020303000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020304000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020305000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020306000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020307000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020308000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020309000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020310000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020311000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020312000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020313000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020314000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020315000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020316000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020317000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020318000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020319000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020320000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020321000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020322000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020323000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020324000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020325000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020326000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020327000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020328000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020329000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020330000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020331000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020332000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020333000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020334000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020335000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020336000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020337000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020338000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020339000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020340000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020341000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020342000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020343000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020344000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020345000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020346000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020347000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020348000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020349000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020350000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020351000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020352000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020353000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020354000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020355000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020356000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020357000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020358000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020359000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020360000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020361000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020362000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020363000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020364000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020365000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_QC_250m_1_doy2020366000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020001000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020002000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020003000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020004000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020005000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020006000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020007000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020008000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020009000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020010000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020011000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020012000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020013000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020014000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020015000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020016000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020017000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020018000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020019000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020020000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020021000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020022000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020023000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020024000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020025000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020026000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020027000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020028000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020029000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020030000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020031000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020032000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020033000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020034000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020035000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020036000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020037000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020038000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020039000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020040000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020041000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020042000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020043000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020044000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020045000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020046000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020047000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020048000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020049000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020050000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020051000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020052000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020053000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020054000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020055000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020056000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020057000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020058000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020059000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020060000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020061000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020062000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b01_1_doy2020063000000_aid0001.tif
# ...
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020236000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020237000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020238000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020239000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020240000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020241000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020242000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020243000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020244000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020245000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020247000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020248000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020249000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020250000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020251000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020252000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020253000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020254000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020255000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020256000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020257000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020258000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020259000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020260000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020261000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020262000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020263000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020264000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020265000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020266000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020267000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020268000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020269000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020270000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020271000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020272000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020273000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020274000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020275000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020276000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020277000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020278000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020279000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020280000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020281000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020282000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020283000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020284000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020285000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020286000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020287000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020288000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020289000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020290000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020291000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020292000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020293000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020294000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020295000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020296000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020297000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020298000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020299000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020300000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020301000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020302000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020303000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020304000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020305000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020306000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020307000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020308000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020309000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020310000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020311000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020312000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020313000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020314000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020315000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020316000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020317000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020318000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020319000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020320000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020321000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020322000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020323000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020324000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020325000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020326000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020327000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020328000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020329000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020330000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020331000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020332000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020333000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020334000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020335000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020336000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020337000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020338000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020339000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020340000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020341000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020342000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020343000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020344000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020345000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020346000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020347000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020348000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020349000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020350000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020351000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020352000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020353000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020354000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020355000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020356000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020357000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020358000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020359000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020360000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020361000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020362000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020363000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020364000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020365000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ.061_sur_refl_b02_1_doy2020366000000_aid0001.tif
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ-061-QC-250m-1-lookup.csv
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ-061-QC-250m-1-Statistics-QA.csv
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/MYD09GQ-061-Statistics.csv
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/try-for-water2-granule-list.txt
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/try-for-water2-request.json
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/try-for-water2-MYD09GQ-061-metadata.xml
# Downloaded: /home/jovyan/shared_space/Galveston_Bay/MODIS_250/README.md

# %% [markdown]
# ### Exploring data

# %% [markdown]
# Initial check

# %%
# %%bash
# gdalinfo /shared_space/Galveston_Bay/MODIS_files/MYD09GQ.061_sur_refl_b02_1_doy2019195000000_aid0001.tif
# Out:
# Driver: GTiff/GeoTIFF
# Files: /shared_space/Galveston_Bay/MODIS_files/MYD09GQ.061_sur_refl_b02_1_doy2019195000000_aid0001.tif
# Size is 961, 721
# Coordinate System is:
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0],
#     UNIT["degree",0.0174532925199433],
#     AUTHORITY["EPSG","4326"]]
# Origin = (-96.002083324732965,30.002083330645590)
# Pixel Size = (0.002083333333147,-0.002083333333147)
# Metadata:
#   add_offset=0.0
#   AREA_OR_POINT=Area
#   scale_factor=0.0001
#   units=Reflectance
# Image Structure Metadata:
#   COMPRESSION=LZW
#   INTERLEAVE=BAND
# Corner Coordinates:
# Upper Left  ( -96.0020833,  30.0020833) ( 96d 0' 7.50"W, 30d 0' 7.50"N)
# Lower Left  ( -96.0020833,  28.5000000) ( 96d 0' 7.50"W, 28d30' 0.00"N)
# Upper Right ( -94.0000000,  30.0020833) ( 94d 0' 0.00"W, 30d 0' 7.50"N)
# Lower Right ( -94.0000000,  28.5000000) ( 94d 0' 0.00"W, 28d30' 0.00"N)
# Center      ( -95.0010417,  29.2510417) ( 95d 0' 3.75"W, 29d15' 3.75"N)
# Band 1 Block=512x512 Type=Int16, ColorInterp=Gray
#   NoData Value=-28672
#   Overviews: 481x361, 241x181, 121x91, 61x46
#   Offset: 0,   Scale:0.0001
# pj_obj_create: Open of /opt/conda/share/proj failed

# %%
#this is all the 250m data for two surface reflectance bands
modis_files = glob.glob("/shared_space/Galveston_Bay/MODIS_files/*.tif")

# %%
fp_250 = modis_files[0]
fp_250
# Out:
# '/shared_space/Galveston_Bay/MODIS_files/MYD09GQ.061_sur_refl_b01_1_doy2019364000000_aid0001.tif'

# %%
test250 = rasterio.open(fp_250)
t_b1 = test250.read(1)
b1_ma = np.ma.masked_values(t_b1, -28672)
b1_ma.max()
# Out:
# 2867

# %%
plt.imshow(b1_ma)
plt.colorbar()

# %% [markdown]
# ## Now the data is in shared space and will go through Quality Control to get rid of clouds

# %% [markdown]
# Want to get rid of days with poor cloud cover

# %%
# Find all QC files
file_dir = Path("/shared_space/Galveston_Bay/MODIS_files")
qc_files = sorted(file_dir.glob("*QC_250m*.tif"))

#function that will compute how much of image is clear
def compute_clear_fraction(qc_path):
    with rasterio.open(qc_path) as src:
        qc = src.read(1)
    # decode bits 0-2
    modland_bits = (qc & 0b11)             # bits 0–1
    cloud_state  = (qc >> 2) & 0b1         # bit 2
    # “Clear” pixels: modland_bits==0 (good) AND cloud_state==0 (clear)
    clear_mask = (modland_bits == 0) & (cloud_state == 0)
    valid_pixels = np.isfinite(qc)
    clear_fraction = clear_mask.sum() / valid_pixels.sum()
    return clear_fraction

# threshold for acceptable cloud cover
cloud_threshold = 0.70  # keep files with >70% clear pixels

# %%
good_files = []
for qc_file in qc_files:
    frac = compute_clear_fraction(qc_file)
    #print(qc_file.name, f"{frac:.2%} clear")
    if frac > cloud_threshold:
        # link to the corresponding surface reflectance bands
        base = qc_file.name.replace("QC_250m_1", "sur_refl_b01_1") #allows check band1
        b01 = qc_file.with_name(base)
        b02 = qc_file.with_name(base.replace("b01", "b02")) #allows to check band2
        #double checks the file exist in the directory
        if b01.exists() and b02.exists():
            good_files.append((b01, b02, qc_file))

print(f"\nFound {len(good_files)} mostly-clear scenes out of {len(qc_files)} total.")
# Out:
# Found 321 mostly-clear scenes out of 365 total.

# %% [markdown]
# The output of good files is a list of tuples. Each tuple contains 3 file paths for the day that had good cloud cover.

# %%
#this just reads the data in a function but I didn't really use this a lot and is not really necessary 
def to_array(path):
    src = rasterio.open(path).read(1)
    array = np.array(src)
    return array #returns 2d array of reflectance values

# %%
test= to_array('/shared_space/Galveston_Bay/MODIS_files/MYD09GQ.061_sur_refl_b01_1_doy2019001000000_aid0001.tif')
np.shape(test)
#type(test)
# Out:
# (721, 961)

# %% [markdown]
# Now using the list of 'good' files, made a netcdf that combines all the files, put into MODIS_test folder

# %%
# Expand ~ first
dest_fp = os.path.expanduser("~/shared_space/Galveston_Bay/MODIS_test")

# Create the directory if it doesn't exist
os.makedirs(dest_fp, exist_ok=True)

# Check properties
print("Exists:", os.path.exists(dest_fp))
print("Is directory:", os.path.isdir(dest_fp))
print("Writable:", os.access(dest_fp, os.W_OK))
print("Saving files to:", dest_fp)

try:
    test_path = os.path.join(dest_fp, "write_test.tmp")
    with open(test_path, "w") as f:
        f.write("test")
    os.remove(test_path)
    print("Write test succeeded.")
except Exception as e:
    print("Write test failed:", e)
# Out:
# Exists: True
# Is directory: True
# Writable: True
# Saving files to: /home/jovyan/shared_space/Galveston_Bay/MODIS_test
# Write test succeeded.

# %%
#creates netCDF for band 1
file = '/home/jovyan/shared_space/Galveston_Bay/MODIS_test/sur_refl_b1_2019.nc'
os.system('rm -f %s' % file)
#Open the file as writable
fp = nc.Dataset(file,'w')

fp.createDimension('x',size=test.shape[1])
fp.createDimension('y',size=test.shape[0])
fp.createDimension('time',size=len(good_files))

var = fp.createVariable('sur_refl_b01', 'f4',dimensions=('time','y','x')) #zlib=True <- this made it run for a long time
var.units = 'reflectance'
var.missing_value = -28672
var.scale_factor = 0.0001

time_var = fp.createVariable('time','f8',dimensions=('time'))
time_var.units = "days since 1970-01-01 00:00:00"
time_var.calendar = "gregorian"


for i, (b1_path, b2_path, qc_path) in enumerate(good_files):
    with rasterio.open(b1_path) as src:
        arr = src.read(1).astype(np.float32)
    var[i,:,:] = arr   # assign into the ith time slice
    
    # Parse DOY from filename
    doy_str = b1_path.name.split("_doy")[1][:7]   # e.g. '2019001'
    date = datetime.strptime(doy_str, "%Y%j")

    # Convert to "days since 1970-01-01"
    time_var[i] = (date - datetime(1970,1,1)).days
    
fp.close()

# %%
#creates netCDF for band 2
file = '/home/jovyan/shared_space/Galveston_Bay/MODIS_test/sur_refl_b2_2019.nc'
os.system('rm -f %s' % file)
#Open the file as writable
fp = nc.Dataset(file,'w')

fp.createDimension('x',size=test.shape[1])
fp.createDimension('y',size=test.shape[0])
fp.createDimension('time',size=len(good_files))

var = fp.createVariable('sur_refl_b02', 'f4',dimensions=('time','y','x'))
var.units = 'reflectance'
var.missing_value = -28672
var.scale_factor = 0.0001

time_var = fp.createVariable('time','f8',dimensions=('time'))
time_var.units = "days since 1970-01-01 00:00:00"
time_var.calendar = "gregorian"


for i, (b1_path, b2_path, qc_path) in enumerate(good_files):
    with rasterio.open(b2_path) as src:
        arr = src.read(1).astype(np.float32)
    var[i,:,:] = arr   # assign into the ith time slice
    
    # Parse DOY from filename
    doy_str = b2_path.name.split("_doy")[1][:7]   # e.g. '2019001'
    date = datetime.strptime(doy_str, "%Y%j")

    # Convert to "days since 1970-01-01"
    time_var[i] = (date - datetime(1970,1,1)).days
    
fp.close()

# %%
t = nc.Dataset('/shared_space/Galveston_Bay/MODIS_files/sur_refl_b1_2019.nc')
t
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes): x(961), y(721), time(321)
#     variables(dimensions): float32 sur_refl_b01(time,y,x), float64 time(time)
#     groups:

# %%
t2 = nc.Dataset('/shared_space/Galveston_Bay/MODIS_files/sur_refl_b2_2019.nc')
t2
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes): x(961), y(721), time(321)
#     variables(dimensions): float32 sur_refl_b02(time,y,x), float64 time(time)
#     groups:

# %%
print(modis_files[0]) #day364
# Out:
# /shared_space/Galveston_Bay/MODIS_files/MYD09GQ.061_sur_refl_b01_1_doy2019364000000_aid0001.tif

# %%
#test to see if it is the same as before put into netcdf
data = t['sur_refl_b01'][319,:,:]   # first time slice (day 0)
data_m = np.ma.masked_values(data, -28672)

plt.imshow(data_m, cmap='viridis')
plt.colorbar(label='Reflectance')
plt.show()

# %% [markdown]
# Same netCDF creation for 2020. I'm realizing after the fact that we probably want the amount of data/the days of data to be the same for each year? The below code finds the 'good' files for 2020, which are a different set of dates than 2019.

# %%
#doing the same for 2020
# Find all QC files
file_dir = Path("/home/jovyan/shared_space/Galveston_Bay/MODIS_250")
qc_files = sorted(file_dir.glob("*QC_250m*.tif"))

#function that will compute how much of image is clear
def compute_clear_fraction(qc_path):
    with rasterio.open(qc_path) as src:
        qc = src.read(1)
    # decode bits 0-2
    modland_bits = (qc & 0b11)             # bits 0–1
    cloud_state  = (qc >> 2) & 0b1         # bit 2
    # “Clear” pixels: modland_bits==0 (good) AND cloud_state==0 (clear)
    clear_mask = (modland_bits == 0) & (cloud_state == 0)
    valid_pixels = np.isfinite(qc)
    clear_fraction = clear_mask.sum() / valid_pixels.sum()
    return clear_fraction

# threshold for acceptable cloud cover
cloud_threshold = 0.70  # keep files with >70% clear pixels

# %%
good_files = []
for qc_file in qc_files:
    frac = compute_clear_fraction(qc_file)
    #print(qc_file.name, f"{frac:.2%} clear")
    if frac > cloud_threshold:
        # link to the corresponding surface reflectance bands
        base = qc_file.name.replace("QC_250m_1", "sur_refl_b01_1") #allows check band1
        b01 = qc_file.with_name(base)
        b02 = qc_file.with_name(base.replace("b01", "b02")) #allows to check band2
        #double checks the file exist in the directory
        if b01.exists() and b02.exists():
            good_files.append((b01, b02, qc_file))

print(f"\nFound {len(good_files)} mostly-clear scenes out of {len(qc_files)} total.")
# Out:
# Found 335 mostly-clear scenes out of 364 total.

# %%
sample = (rasterio.open(good_files[0][0]).read(1))
np.shape(sample)
# Out:
# (721, 961)

# %%
#band 1
file = '/home/jovyan/shared_space/Galveston_Bay/MODIS_test/sur_refl_b1_2020.nc'
os.system('rm -f %s' % file)
#Open the file as writable
fp = nc.Dataset(file,'w')

fp.createDimension('x',size=sample.shape[1])
fp.createDimension('y',size=sample.shape[0])
fp.createDimension('time',size=len(good_files))

var = fp.createVariable('sur_refl_b01', 'f4',dimensions=('time','y','x'))
var.units = 'reflectance'
var.missing_value = -28672
var.scale_factor = 0.0001

time_var = fp.createVariable('time','f8',dimensions=('time'))
time_var.units = "days since 1970-01-01 00:00:00"
time_var.calendar = "gregorian"


for i, (b1_path, b2_path, qc_path) in enumerate(good_files):
    with rasterio.open(b1_path) as src:
        arr = src.read(1).astype(np.float32)
    var[i,:,:] = arr   # assign into the ith time slice
    
    # Parse DOY from filename
    doy_str = b1_path.name.split("_doy")[1][:7]   # e.g. '2019001'
    date = datetime.strptime(doy_str, "%Y%j")

    # Convert to "days since 1970-01-01"
    time_var[i] = (date - datetime(1970,1,1)).days
    
fp.close()

# %%
#band 2
file = '/home/jovyan/shared_space/Galveston_Bay/MODIS_test/sur_refl_b2_2020.nc'
os.system('rm -f %s' % file)
#Open the file as writable
fp = nc.Dataset(file,'w')

fp.createDimension('x',size=sample.shape[1])
fp.createDimension('y',size=sample.shape[0])
fp.createDimension('time',size=len(good_files))

var = fp.createVariable('sur_refl_b01', 'f4',dimensions=('time','y','x'))
var.units = 'reflectance'
var.missing_value = -28672
var.scale_factor = 0.0001

time_var = fp.createVariable('time','f8',dimensions=('time'))
time_var.units = "days since 1970-01-01 00:00:00"
time_var.calendar = "gregorian"


for i, (b1_path, b2_path, qc_path) in enumerate(good_files):
    with rasterio.open(b2_path) as src:
        arr = src.read(1).astype(np.float32)
    var[i,:,:] = arr   # assign into the ith time slice
    
    # Parse DOY from filename
    doy_str = b2_path.name.split("_doy")[1][:7]   # e.g. '2019001'
    date = datetime.strptime(doy_str, "%Y%j")

    # Convert to "days since 1970-01-01"
    time_var[i] = (date - datetime(1970,1,1)).days
    
fp.close()
