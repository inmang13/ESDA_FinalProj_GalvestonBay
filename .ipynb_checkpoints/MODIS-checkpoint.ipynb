# %%
import glob
import os

#set current working directory
os.chdir('/home/jovyan')

#list files in shared folder
files = glob.glob("/shared_space/Galveston_Bay/*")
files

# %%
test!
# Out:
#   File "<ipython-input-1-5953b27e02a2>", line 1
#     test!
#         ^
# SyntaxError: invalid syntax
